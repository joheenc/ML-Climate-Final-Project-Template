# %%
import matplotlib.pyplot as plt
import numpy as np
jan = np.array([0.30959306, 0.20310572, 0.10372289, 0.08809556, 0.0872429 ,
       0.08148687, 0.07323495, 0.02925724, 0.01478852, 0.00597381])
apr = np.array([0.31449921, 0.19461346, 0.12625726, 0.0911936 , 0.08833841,
       0.08106936, 0.045487  , 0.02925115, 0.01751659, 0.00696413])
jul = np.array([0.30637787, 0.2148168 , 0.09366379, 0.08965372, 0.08487036,
       0.0730699 , 0.07128218, 0.02820202, 0.01977622, 0.01131506])
oct = np.array([0.31748917, 0.19461862, 0.10696867, 0.0871308 , 0.08337909,
       0.07902404, 0.0689269 , 0.02399946, 0.01903263, 0.01239927])
jan_frac = []
for i in range(11):
    jan_frac.append(np.sum(jan[:i]))
apr_frac = []
for i in range(11):
    apr_frac.append(np.sum(apr[:i]))
jul_frac = []
for i in range(11):
    jul_frac.append(np.sum(jul[:i]))
oct_frac = []
for i in range(11):
    oct_frac.append(np.sum(oct[:i]))
plt.plot(jan_frac, marker='o', color='r', label='Jan', alpha=1)
plt.plot(apr_frac, marker='o', color='g', label='Apr', alpha=0.7)
plt.plot(jul_frac, marker='o', color='b', label='Jul', alpha=0.4)
plt.plot(oct_frac, marker='o', color='k', label='Oct', alpha=0.1)
plt.legend()
plt.xlabel('PC number')
plt.ylabel('Variance Fraction (%)')
# Out:
# Text(0, 0.5, 'Variance Fraction (%)')
